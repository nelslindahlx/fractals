# %% [markdown]
# <a href="https://colab.research.google.com/github/nelslindahlx/fractals/blob/main/code_to_make_a_mandelbrot_fractal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# "provide code to make fractal that changes colors"
# https://chat.openai.com/share/07ef044a-5409-40f8-b848-fc147d81cd2e

# %%
import numpy as np
import matplotlib.pyplot as plt

def mandelbrot(c, max_iter):
    z = c
    for n in range(max_iter):
        if abs(z) > 2:
            return n
        z = z*z + c
    return max_iter

def mandelbrot_set(xmin, xmax, ymin, ymax, width, height, max_iter):
    r1 = np.linspace(xmin, xmax, width)
    r2 = np.linspace(ymin, ymax, height)
    return (r1, r2, np.array([[mandelbrot(complex(r, i), max_iter) for r in r1] for i in r2]))

xmin, xmax = -2.0, 2.0
ymin, ymax = -2.0, 2.0
width, height = 1000, 1000
max_iter = 512

# Generate the Mandelbrot set
x, y, mandelbrot_data = mandelbrot_set(xmin, xmax, ymin, ymax, width, height, max_iter)

# Create a colormap in shades of blue
cmap = plt.cm.get_cmap('Blues')

# Display the fractal in shades of blue
plt.figure(figsize=(10, 10))
plt.imshow(mandelbrot_data.T, cmap=cmap, extent=(xmin, xmax, ymin, ymax))
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# <ipython-input-8-50532596fb98>:26: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Blues')

# %%
import numpy as np
import matplotlib.pyplot as plt

def mandelbrot(c, max_iter):
    z = c
    for n in range(max_iter):
        if abs(z) > 2:
            return n
        z = z*z + c
    return max_iter

def mandelbrot_set(xmin, xmax, ymin, ymax, width, height, max_iter):
    r1 = np.linspace(xmin, xmax, width)
    r2 = np.linspace(ymin, ymax, height)
    return (r1,r2,np.array([[mandelbrot(complex(r, i), max_iter) for r in r1] for i in r2]))

xmin, xmax = -2.0, 1.0
ymin, ymax = -1.5, 1.5
width, height = 1000, 1000
max_iter = 256

# Generate the Mandelbrot set
x, y, mandelbrot_data = mandelbrot_set(xmin, xmax, ymin, ymax, width, height, max_iter)

# Create a colormap that changes over time
colors = np.arange(max_iter)
np.random.shuffle(colors)

# Display the fractal with changing colors
plt.figure(figsize=(10, 10))
plt.imshow(mandelbrot_data.T, cmap=plt.cm.twilight_shifted, extent=(xmin, xmax, ymin, ymax))
plt.xticks([])
plt.yticks([])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def mandelbrot(c, max_iter):
    z = c
    for n in range(max_iter):
        if abs(z) > 2:
            return n
        z = z*z + c
    return max_iter

def mandelbrot_set(xmin, xmax, ymin, ymax, width, height, max_iter):
    r1 = np.linspace(xmin, xmax, width)
    r2 = np.linspace(ymin, ymax, height)
    return (r1,r2,np.array([[mandelbrot(complex(r, i), max_iter) for r in r1] for i in r2]))

xmin, xmax = -2.0, 1.0
ymin, ymax = -1.5, 1.5
width, height = 1000, 1000
max_iter = 256

# Generate the Mandelbrot set
x, y, mandelbrot_data = mandelbrot_set(xmin, xmax, ymin, ymax, width, height, max_iter)

# Create a colormap in shades of blue
cmap = plt.cm.get_cmap('Blues')

# Display the fractal in shades of blue
plt.figure(figsize=(10, 10))
plt.imshow(mandelbrot_data.T, cmap=cmap, extent=(xmin, xmax, ymin, ymax))
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# <ipython-input-7-9c1234ccdfb6>:26: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('Blues')
